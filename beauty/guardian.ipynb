# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import json
import re
from datetime import datetime
import os
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from requests.exceptions import InvalidURL
from unidecode import unidecode
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 11
#       9 from urllib3.util.retry import Retry
#      10 from requests.exceptions import InvalidURL
# ---> 11 from unidecode import unidecode
#
# ModuleNotFoundError: No module named 'unidecode'

# %%
def extract_link(base_url):
    # Headers for request
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36"}
    page = 1
    all_links = []
    max_pages = 12  # Set maximum number of pages to navigate

    while page <= max_pages:
        url = f'{base_url}?p={page}'
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # New lines
        a_tags = soup.find_all('a', class_='product-item-link')
        all_links.extend([tag.get('href') for tag in a_tags])
        
        # Increment page number for the next iteration
        page += 1

    return all_links

# %%
def extract_data(all_links, start, end):
    data = []
    for link in all_links[start:end]:
        headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36"}
        try:
            response = requests.get(link, headers=headers)
            response.raise_for_status()  # Raise an error for bad status codes
        except (requests.exceptions.RequestException, InvalidURL) as e:
            print(f"Skipping URL due to error: {link} - {e}")
            continue
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # image_link
        image_link_meta = soup.find('meta', attrs={'property': 'og:image'})
        image_link = image_link_meta['content'].strip() if image_link_meta else None

        # rating
        rating_element = soup.find('div', class_='rating-result')
        rating = rating_element.get('title').replace('%', '') if rating_element else None
        rating_count_element = soup.find('div', class_='reviews-actions')
        rating_count = ''.join(filter(str.isdigit, rating_count_element.get_text())) if rating_count_element else None

        # Price
        price_element = soup.find('span', class_='price-wrapper', attrs={'data-price-type': 'finalPrice'})
        price = price_element.get('data-price-amount') if price_element else None
        listing_price_element = soup.find('span', class_='price-wrapper', attrs={'data-price-type': 'oldPrice'})
        listing_price = listing_price_element.get('data-price-amount') if listing_price_element else None
        
        # SKU
        sku_element = soup.find('div', class_='product attribute sku')
        sku = sku_element.find('div', class_='value').get_text(strip=True) if sku_element else None

        # sku_name
        sku_name_meta = soup.find('meta', attrs={'property': 'og:title'})
        sku_name = sku_name_meta['content'].strip() if sku_name_meta else None

        # brand
        brand_element = soup.find('div', id='logo_name_brand')
        brand = brand_element.find('span', class_='brand-name').get_text(strip=True) if brand_element else None

        # status
        status_element = soup.select_one('.action.primary.tocart.action-tocart-sticky')
        status = status_element.get_text(strip=True) if status_element else None

        # voucher
        voucher_elements = soup.select('div.saving-voucher ul.saving-voucher-ul li.rule-desc-detail')
        vouchers = [voucher.get_text(strip=True) for voucher in voucher_elements]

        # gift
        gifts = []
        gift_elements = soup.select('div.product_info_promo')
        for gift in gift_elements:
            product_name = gift.find('a', class_='ampromo-product-name').text.strip()
            old_price = gift.find('span', class_='ampromo-product-oldPrice').text.strip().replace('₫', '').replace(',', '')
            gifts.append(f"{product_name} - {old_price}")

        # Extracting all info sections (e.g., Giới thiệu, Công dụng)
        info_sections = {}
        # Find all headers and corresponding content sections
        headers = soup.find_all('a', class_='data switch')
        content_sections = soup.find_all('div', class_='data item content')

        # Loop through both headers and contents
        for header_element, content_element in zip(headers, content_sections):
            header = header_element.get_text(strip=True)
            content = content_element.get_text(strip=True)
            info_sections[header] = content

        data.append({
            'url': link,
            'sku': sku,
            'image_link': image_link,
            'sku_name': sku_name,
            'rating': rating,
            'rating_count': rating_count,
            'price': price,
            'listing_price': listing_price,
            'brand': brand,
            'status': status,
            'vouchers': vouchers,
            'gifts': gifts,
            'info_sections': info_sections
        })
    return data

# %%
def save_data(data):
    df = pd.DataFrame(data)
    df['date'] = pd.Timestamp.now().normalize()

    df2 = df.copy()
    
    # Ensure `info_sections` is a dictionary, convert from string if necessary
    df2['info_sections'] = df2['info_sections'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
    info_df = pd.json_normalize(df2['info_sections'])  # Converts dictionary into a DataFrame with keys as columns
    df2 = pd.concat([df2, info_df], axis=1)  # Concatenate the expanded info sections

    # Filepath for the CSV file
    file_path1 = 'guardian.csv'
    file_path2 = 'guardian_info.csv'

    # Append the new data to the existing CSV file
    if os.path.exists(file_path1):
        df.to_csv(file_path1, mode='a', index=False, header=False, encoding='utf-8-sig')
    else:
        df.to_csv(file_path1, index=False, encoding='utf-8-sig')

    if os.path.exists(file_path2):
        df2.to_csv(file_path2, mode='a', index=False, header=False, encoding='utf-8-sig')
    else:
        df2.to_csv(file_path2, index=False, encoding='utf-8-sig')
        
    return df2

# %% [markdown]
# # 1. Get all links

# %%
all_links = []
all_links.extend(extract_link('https://www.guardian.com.vn/cham-soc-da-mat/chong-nang.html'))

# %%
all_links.extend(extract_link('https://www.guardian.com.vn/cham-soc-da-mat/tay-trang.html'))

# %%
len(all_links)
# Out:
# 265

# %%
all_links = list(dict.fromkeys(all_links))
len(all_links)
# Out:
# 265

# %% [markdown]
# # 2. Extract data

# %%
data = []
x = 0
y = 25
z = 25
data.extend(extract_data(all_links,x,y))

# %%
import time
max_retries = 5   # number of retry attempts per iteration
retry_delay = 3   # seconds between retries

data = []

while x < len(all_links):  # or some stopping condition
    y = x + z

    attempt = 0
    while attempt < max_retries:
        try:
            data.extend(extract_data(all_links, x, y))
            print(f"Extracted: x={x}, y={y}")
            break  # exit retry loop on success
        except Exception as e:
            attempt += 1
            print(f"Error at x={x}, y={y} | Attempt {attempt}/{max_retries} | {e}")
            if attempt == max_retries:
                print("Skipping this batch and continuing")
            else:
                time.sleep(retry_delay)

    x = y  # move to next batch

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))
print(x,y) #300
# Out:
# 275 300

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))
print(x,y)
# Out:
# 750 775

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))
print(x,y)
# Out:
# 825 850

# %%
x = x+z
y = y+z
data.extend(extract_data(all_links,x,y))

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#                                                    url      sku  \
# 0    https://www.guardian.com.vn/kem-chong-nang-mon...  3030949
# 1    https://www.guardian.com.vn/kem-chong-nang-l-o...  3027053
# 2    https://www.guardian.com.vn/gel-chong-nang-cap...  3025476
# 3    https://www.guardian.com.vn/kem-chong-nang-cho...  3024648
# 4    https://www.guardian.com.vn/kem-chong-nang-kie...  3016733
# ..                                                 ...      ...
# 260  https://www.guardian.com.vn/nuoc-tay-trang-pro...  3025187
# 261  https://www.guardian.com.vn/dau-tay-trang-lam-...  3027315
# 262  https://www.guardian.com.vn/khan-uot-tay-trang...  3028453
# 263  https://www.guardian.com.vn/tay-trang-mi-judyd...  3030706
# 264  https://www.guardian.com.vn/nuoc-tay-trang-dan...  3030965
#
#                                             image_link  \
# 0    https://www.guardian.com.vn/media/catalog/prod...
# 1    https://www.guardian.com.vn/media/catalog/prod...
# 2    https://www.guardian.com.vn/media/catalog/prod...
# 3    https://www.guardian.com.vn/media/catalog/prod...
# 4    https://www.guardian.com.vn/media/catalog/prod...
# ..                                                 ...
# 260  https://www.guardian.com.vn/media/catalog/prod...
# 261  https://www.guardian.com.vn/media/catalog/prod...
# 262  https://www.guardian.com.vn/media/catalog/prod...
# 263  https://www.guardian.com.vn/media/catalog/prod...
# 264  https://www.guardian.com.vn/media/catalog/prod...
#
#                                               sku_name rating rating_count  \
# 0          KEM CHỐNG NẮNG BLISSBERRY DƯỠNG  TRẮNG 60ML      0            0
# 1    Kem Chống Nắng L'Oreal Mỏng Nhẹ Bảo Vệ Tối Đa ...     95            4
# 2    Gel Chống Nắng Cấp Ẩm, Nâng Tông Chiết Xuất Ý ...     80            1
# 3    Kem Chống Nắng Cho Da Nhạy Cảm Skin1004 Madaga...     95            8
# 4    Kem Chống Nắng Kiểm Soát Nhờn Không Màu La Roc...     93            3
# ..                                                 ...    ...          ...
# 260  Nước Tẩy Trang Professional Clean Eye & Lip Re...      0            0
# 261       Dầu Tẩy Trang Làm Sạch Cân Bằng Coboté 150Ml      0            0
# 262  KHĂN TẨY TRANG TẠO BỌT GUARDIAN AMINO ACID BUB...      0            0
# 263        TẨY TRANG MI JUDYDOLL MASCARA REMOVER - 5ML      0            0
# 264  Nước Tẩy Trang Dành Cho Da Dầu Mụn Simple Puri...      0            0
#
#       price listing_price             brand                status  \
# 0    379000         97000        BLISSBERRY  Thêm vào giỏ hàng
# 1    299000        379000           L'ORÉAL  Thêm vào giỏ hàng
# 2    143000        179000  REIHAKU HATOMUGI  Thêm vào giỏ hàng
# 3    249000        445000          SKIN1004  Thêm vào giỏ hàng
# 4    365000        560000    LA ROCHE-POSAY  Thêm vào giỏ hàng
# ..      ...           ...               ...                   ...
# 260   99000        229000        CATHY DOLL  Thêm vào giỏ hàng
# 261  220000         65000            COBOTÉ           Sắp về hàng
# 262   69000         99000          GUARDIAN  Thêm vào giỏ hàng
# 263  167000        186000          JUDYDOLL  Thêm vào giỏ hàng
# 264  149000        198000            SIMPLE  Thêm vào giỏ hàng
#
#                                               vouchers  \
# 0    [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 1    [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 2    [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 3    [VoucherG-DN- Giảm 60K cho đơn hàng có địa chỉ...
# 4    [VoucherG-DN- Giảm 60K cho đơn hàng có địa chỉ...
# ..                                                 ...
# 260  [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 261                                                 []
# 262  [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 263  [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 264  [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
#
#                                                  gifts  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [[HÀNG TẶNG KHÔNG BÁN] Kem Chống Nắng Dạng Tuý...
# 4    [LA ROCHE-POSAY TÚI TÍM MELA B3 - 50000, [HÀNG...
# ..                                                 ...
# 260                                                 []
# 261                                                 []
# 262                                                 []
# 263  [FG JUDYDOLL LUOC HOA MINI - 119000, [Hàng Tặn...
# 264                                                 []
#
#                                          info_sections
# 0    {'Giới Thiệu': 'Kem Chống Nắng Mỏng Nhẹ Dưỡng ...
# 1    {'Giới Thiệu': 'Kem Chống Nắngthương hiệuL’Ore...
# 2    {'Giới Thiệu': 'Gel Chống NắngCấp Ẩm, Nâng Tôn...
# 3    {'Giới Thiệu': 'Kem Chống Nắng Cho Da Nhạy Cảm...
# 4    {'Giới Thiệu': 'Kem Chống Nắng La Roche-Posay ...
# ..                                                 ...
# 260  {'Giới Thiệu': 'Nước Tẩy Trang Professional Cl...
# 261  {'Giới Thiệu': 'THÀNH PHẦN - INGREDIENTS:Dầu d...
# 262  {'Giới Thiệu': 'Khăn Ướt Tẩy Trang Giúp Làm Sạ...
# 263  {'Giới Thiệu': 'Tẩy Trang Mi Judydoll Mascara ...
# 264  {'Giới Thiệu': 'Nước Tẩy Trang Dành Cho Da Dầu...
#
# [265 rows x 13 columns]

# %%
save_data(data)
# Out:
#                                                    url      sku  \
# 0    https://www.guardian.com.vn/kem-chong-nang-mon...  3030949
# 1    https://www.guardian.com.vn/kem-chong-nang-l-o...  3027053
# 2    https://www.guardian.com.vn/gel-chong-nang-cap...  3025476
# 3    https://www.guardian.com.vn/kem-chong-nang-cho...  3024648
# 4    https://www.guardian.com.vn/kem-chong-nang-kie...  3016733
# ..                                                 ...      ...
# 260  https://www.guardian.com.vn/nuoc-tay-trang-pro...  3025187
# 261  https://www.guardian.com.vn/dau-tay-trang-lam-...  3027315
# 262  https://www.guardian.com.vn/khan-uot-tay-trang...  3028453
# 263  https://www.guardian.com.vn/tay-trang-mi-judyd...  3030706
# 264  https://www.guardian.com.vn/nuoc-tay-trang-dan...  3030965
#
#                                             image_link  \
# 0    https://www.guardian.com.vn/media/catalog/prod...
# 1    https://www.guardian.com.vn/media/catalog/prod...
# 2    https://www.guardian.com.vn/media/catalog/prod...
# 3    https://www.guardian.com.vn/media/catalog/prod...
# 4    https://www.guardian.com.vn/media/catalog/prod...
# ..                                                 ...
# 260  https://www.guardian.com.vn/media/catalog/prod...
# 261  https://www.guardian.com.vn/media/catalog/prod...
# 262  https://www.guardian.com.vn/media/catalog/prod...
# 263  https://www.guardian.com.vn/media/catalog/prod...
# 264  https://www.guardian.com.vn/media/catalog/prod...
#
#                                               sku_name rating rating_count  \
# 0          KEM CHỐNG NẮNG BLISSBERRY DƯỠNG  TRẮNG 60ML      0            0
# 1    Kem Chống Nắng L'Oreal Mỏng Nhẹ Bảo Vệ Tối Đa ...     95            4
# 2    Gel Chống Nắng Cấp Ẩm, Nâng Tông Chiết Xuất Ý ...     80            1
# 3    Kem Chống Nắng Cho Da Nhạy Cảm Skin1004 Madaga...     95            8
# 4    Kem Chống Nắng Kiểm Soát Nhờn Không Màu La Roc...     93            3
# ..                                                 ...    ...          ...
# 260  Nước Tẩy Trang Professional Clean Eye & Lip Re...      0            0
# 261       Dầu Tẩy Trang Làm Sạch Cân Bằng Coboté 150Ml      0            0
# 262  KHĂN TẨY TRANG TẠO BỌT GUARDIAN AMINO ACID BUB...      0            0
# 263        TẨY TRANG MI JUDYDOLL MASCARA REMOVER - 5ML      0            0
# 264  Nước Tẩy Trang Dành Cho Da Dầu Mụn Simple Puri...      0            0
#
#       price listing_price             brand                status  \
# 0    379000         97000        BLISSBERRY  Thêm vào giỏ hàng
# 1    299000        379000           L'ORÉAL  Thêm vào giỏ hàng
# 2    143000        179000  REIHAKU HATOMUGI  Thêm vào giỏ hàng
# 3    249000        445000          SKIN1004  Thêm vào giỏ hàng
# 4    365000        560000    LA ROCHE-POSAY  Thêm vào giỏ hàng
# ..      ...           ...               ...                   ...
# 260   99000        229000        CATHY DOLL  Thêm vào giỏ hàng
# 261  220000         65000            COBOTÉ           Sắp về hàng
# 262   69000         99000          GUARDIAN  Thêm vào giỏ hàng
# 263  167000        186000          JUDYDOLL  Thêm vào giỏ hàng
# 264  149000        198000            SIMPLE  Thêm vào giỏ hàng
#
#                                               vouchers  \
# 0    [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 1    [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 2    [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 3    [VoucherG-DN- Giảm 60K cho đơn hàng có địa chỉ...
# 4    [VoucherG-DN- Giảm 60K cho đơn hàng có địa chỉ...
# ..                                                 ...
# 260  [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 261                                                 []
# 262  [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 263  [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
# 264  [VoucherG-LAMQUEN- GIẢM 10% TỐI ĐA 30K CHO ĐƠN...
#
#                                                  gifts  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [[HÀNG TẶNG KHÔNG BÁN] Kem Chống Nắng Dạng Tuý...
# 4    [LA ROCHE-POSAY TÚI TÍM MELA B3 - 50000, [HÀNG...
# ..                                                 ...
# 260                                                 []
# 261                                                 []
# 262                                                 []
# 263  [FG JUDYDOLL LUOC HOA MINI - 119000, [Hàng Tặn...
# 264                                                 []
#
#                                          info_sections       date  \
# 0    {'Giới Thiệu': 'Kem Chống Nắng Mỏng Nhẹ Dưỡng ... 2024-11-27
# 1    {'Giới Thiệu': 'Kem Chống Nắngthương hiệuL’Ore... 2024-11-27
# 2    {'Giới Thiệu': 'Gel Chống NắngCấp Ẩm, Nâng Tôn... 2024-11-27
# 3    {'Giới Thiệu': 'Kem Chống Nắng Cho Da Nhạy Cảm... 2024-11-27
# 4    {'Giới Thiệu': 'Kem Chống Nắng La Roche-Posay ... 2024-11-27
# ..                                                 ...        ...
# 260  {'Giới Thiệu': 'Nước Tẩy Trang Professional Cl... 2024-11-27
# 261  {'Giới Thiệu': 'THÀNH PHẦN - INGREDIENTS:Dầu d... 2024-11-27
# 262  {'Giới Thiệu': 'Khăn Ướt Tẩy Trang Giúp Làm Sạ... 2024-11-27
# 263  {'Giới Thiệu': 'Tẩy Trang Mi Judydoll Mascara ... 2024-11-27
# 264  {'Giới Thiệu': 'Nước Tẩy Trang Dành Cho Da Dầu... 2024-11-27
#
#                                             Giới Thiệu  \
# 0    Kem Chống Nắng Mỏng Nhẹ Dưỡng Da Blissberry Gl...
# 1    Kem Chống Nắngthương hiệuL’OrealParis UV Defen...
# 2    Gel Chống NắngCấp Ẩm, Nâng Tông Chiết Xuất Ý D...
# 3    Kem Chống Nắng Cho Da Nhạy Cảm Skin1004 Madaga...
# 4    Kem Chống Nắng La Roche-Posay Kiềm Dầu 12H Ant...
# ..                                                 ...
# 260  Nước Tẩy Trang Professional Clean Eye & Lip Re...
# 261  THÀNH PHẦN - INGREDIENTS:Dầu dừa tươi™ chiết x...
# 262  Khăn Ướt Tẩy Trang Giúp Làm Sạch Da Guardian A...
# 263  Tẩy Trang Mi Judydoll Mascara Remover 5MlTẩy t...
# 264  Nước Tẩy Trang Dành Cho Da Dầu Mụn Simple Puri...
#
#                                              Công Dụng  \
# 0    CÔNG DỤNG CHÍNH:Chống nắng phổ rộng với chỉ số...
# 1    20X kết cấu mỏng nhẹ:kem chống nắng dạng sữa l...
# 2    CÔNG DỤNG CHÍNHChiết xuất hạt ý dĩ cung cấp gi...
# 3    Có khả năng bảo vệ da dưới ánh nắng mặt trời t...
# 4    Không gây bết dính, không để lại vệt t...
# ..                                                 ...
# 260                                                NaN
# 261                                                NaN
# 262  CÔNG DỤNG CHÍNH:Khăn ướt làm sạch Guardian Ami...
# 263  CÔNG DỤNG CHÍNH:Tẩy trang mi JUDYDOLL sở hữu c...
# 264  CÔNG DỤNG CHÍNH:Chiết xuất cây phỉ Witch Hazel...
#
#                                             Thành Phần  \
# 0    THÀNH PHẦN:Chống nắng tối ưu, hiệu quả nhờ các...
# 1                             Xem trên bao bì sản phẩm
# 2    Thành phần:Water, Ethylhexyl Methoxycinnamate,...
# 3                             Xem trên bao bì sản phẩm
# 4    - Màng lọc độc quyền MEXORYL 400:Màng lọc UV d...
# ..                                                 ...
# 260                                                NaN
# 261                                                NaN
# 262  THÀNH PHẦN:Aqua, Cocamidopropyl Betaine, Sodiu...
# 263  THÀNH PHẦN:Isohexadecane, Isododecane, Triethy...
# 264       THÀNH PHẦN:Xem chi tiết trên bao bì sản phẩm
#
#                                      Hướng Dẫn Sử Dụng  \
# 0    CÁCH DÙNG:Bước 1: Lắc đều trước khi sử dụng.Bư...
# 1    - Dùng 1 lượng kem vừa đủ và chia đều trên mặt...
# 2    CÁCH DÙNG- Thoa kem trước khi tiếp xúc với á...
# 3    - Lắc đều trước khi sử dụng- Sử dụng ở bước cu...
# 4    - Thoa kem trước khi tiếp xúc với ánh nắng 20 ...
# ..                                                 ...
# 260                                                NaN
# 261                                                NaN
# 262  Chú ý:- Chỉ sử dụng ngoài da.- Thử sản phẩm tr...
# 263  HƯỚNG DẪN SỬ DỤNG:- Lấy lượng sản phẩm vừa đủ ...
# 264  CÁCH DÙNG:Bước 1: Cho một lượng nước tẩy trang...
#
#                                         Thông tin thêm
# 0    Thông tin thêmXuất xứ thương hiệuKorea (the Re...
# 1    Thông tin thêmDành cho daMọi Loại DaXuất xứ th...
# 2    Thông tin thêmDành cho daMọi Loại DaXuất xứ th...
# 3    Thông tin thêmDành cho daDa Nhạy CảmXuất xứ th...
# 4    Thông tin thêmDành cho daMọi Loại DaXuất xứ th...
# ..                                                 ...
# 260  Thông tin thêmDành cho daMọi Loại DaXuất xứ th...
# 261  Thông tin thêmDành cho daMọi Loại DaXuất xứ th...
# 262  Thông tin thêmDành cho daMọi Loại DaXuất xứ th...
# 263  Thông tin thêmXuất xứ thương hiệuChinaHạn sử d...
# 264  Thông tin thêmXuất xứ thương hiệuThailandHạn s...
#
# [265 rows x 19 columns]
